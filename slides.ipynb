# %% [markdown]
# # How to make a slideshow jupyter notebook in JupyterLab

# %% [markdown]
# ### Step 1

# %% [markdown]
# In the sidebar, select "Slide" under "Slide Type" and repeat for all slides (shown below).

# %%
from IPython.display import Image
Image(filename="../../Desktop/jl-slides.png")

# %% [markdown]
# ### Step 2

# %% [markdown]
# Next, add your slideshow to github, using either the command line (not shown), GitHub Desktop (not shown), or using your browser to navigate to your GitHub repo and clicking "Upload files" (shown below) and then dragging and dropping or selecting the notebook file.

# %%
Image(filename="../../Desktop/jl-slide3.png")

# %%
Image(filename="../../Desktop/jl-slide4.png")

# %% [markdown]
# ### Step 3A

# %% [markdown]
# Once your notebook is on GitHub. You can obtain the link to your slides by changing the 3 variables below and running these 2 code cells:

# %%
username = "marskar"
reponame = "biof309_spring2018"
filename = "slides.ipynb"

# %%
"http://nbviewer.jupyter.org/format/slides/github/" \
+ username + "/" + reponame  + "/blob/master/" + filename
# Out:
# 'http://nbviewer.jupyter.org/format/slides/github/marskar/biof309_spring2018/blob/master/slides.ipynb'

# %% [markdown]
# ### Step 3B

# %% [markdown]
# Another way to get the link, is to go to [nbviewer](http://nbviewer.jupyter.org/) and paste the url to your slides in the text field.

# %% [markdown]
# Then click on the present icon (shown below).

# %%
Image(filename="../../Desktop/jl-slide5.png")

# %% [markdown]
# ### Bonus

# %% [markdown]
# If you want to export your slides as an html slideshow:

# %% [markdown]
# In the top left, under "File", click "Export Notebook As..." then "Reveal.js Slides"

# %%
Image(filename="../../Desktop/jl-slides2.png", height=150)
